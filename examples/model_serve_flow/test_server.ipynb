# %%
! pip install openai
# Out:
# Requirement already satisfied: openai in /opt/app-root/lib64/python3.12/site-packages (2.8.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/app-root/lib64/python3.12/site-packages (from openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/app-root/lib64/python3.12/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/app-root/lib64/python3.12/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/app-root/lib64/python3.12/site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/app-root/lib64/python3.12/site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in /opt/app-root/lib64/python3.12/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /opt/app-root/lib64/python3.12/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/app-root/lib64/python3.12/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /opt/app-root/lib64/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /opt/app-root/lib64/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /opt/app-root/lib64/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/app-root/lib64/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/app-root/lib64/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/app-root/lib64/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/app-root/lib64/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)

# %%
from openai import OpenAI

# %%
def init_llm(base_url: str = "http://127.0.0.1:8000/v1", api_key: str = "empty", model: str = None):
        """Initialize with required API key and model name. 
        Args:
            base_url(str): url where vLLM server is running
            api_key (str): API key
            model (str): Model served using vLLM (e.g., Qwen/Qwen2.5-1.5B-Instruct)
        """  
        llm = OpenAI(base_url=base_url, api_key=api_key)
        model = model
        return llm, model
        

def invoke(llm, model, messages: list) -> str:
        """Get complete response.
        Args:
            messages (list): List of messages in the chat format.
        returns: str: Complete response from the LLM
        """
        response = llm.chat.completions.create( 
        model=model,
        messages=messages,
        seed=42
    )
        return response.choices[0].message.content

def stream(llm, model, messages: list):
    """Stream response token by token.
    Args:
        messages (list): List of messages in the chat format.
    yields: str: Yields response token by token.
    """
    stream = llm.chat.completions.create(
        model=model,
        messages=messages,
        stream=True,
        seed=42
    )
    for chunk in stream:
        if content := chunk.choices[0].delta.content:
            yield content

# %%
# Testing vLLM server
llm, model = init_llm(base_url="http://127.0.0.1:8000/v1",
                       api_key="empty")
messages=[{"role": "user", "content": "Explain quantum computing simply."}]
response = invoke(llm, model, messages)

# %%
response
# Out:
# 'Quantum computing refers to the science and technology of manipulating quantum systems to solve complex problems that are currently out of reach for classical computing technologies. Essentially, it is a branch of computing that involves using the properties of quantum mechanics to perform computations using qubits, which are quantum bits (or "bits").\n\nOne of the distinct features of quantum computing is that it operates on the principles of quantum mechanics, rather than classical mechanics, such as Newtonian laws of motion. This quantum weirdness means that mathematical problems that are traditionally considered intractable by classical physics can be solved using quantum mechanics, and indeed, quantum computing has shown considerable promise for large-scale problems in fields such as cryptography, drug design, and optimization.\n\nIn terms of application scenarios, quantum computing could potentially play a small but valuable role in scientific and financial applications such as medical imaging, artificial intelligence, and prognostic modeling, but it is still a far cry from displacing classical computers. It is being developed in various contexts, but effort is needed to systematically integrate the necessary components to create reliable systems. \n\nIn the future, quantum computing is expected to advance at an exponential rate, unlocking new capabilities that will challenge classical computing capabilities. While the barrier to entry may continue to be high, the promise of leveraging quantum mechanics to solve complex problems is indisputable.'

# %%
response = ""
for chunk in stream(llm, model, messages):
    response += chunk
    print(chunk, end="", flush=True)
# Out:
# Quantum computing refers to the science and technology of manipulating quantum systems to solve complex problems that are currently out of reach for classical computing technologies. Essentially, it is a branch of computing that involves using the properties of quantum mechanics to perform computations using qubits, which are quantum bits (or "bits").
#
# One of the distinct features of quantum computing is that it operates on the principles of quantum mechanics, rather than classical mechanics, such as Newtonian laws of motion. This quantum weirdness means that mathematical problems that are traditionally considered intractable by classical physics can be solved using quantum mechanics, and indeed, quantum computing has shown considerable promise for large-scale problems in fields such as cryptography, drug design, and optimization.
#
# In terms of application scenarios, quantum computing could potentially play a small but valuable role in scientific and financial applications such as medical imaging, artificial intelligence, and prognostic modeling, but it is still a far cry from displacing classical computers. It is being developed in various contexts, but effort is needed to systematically integrate the necessary components to create reliable systems.
#
# In the future, quantum computing is expected to advance at an exponential rate, unlocking new capabilities that will challenge classical computing capabilities. While the barrier to entry may continue to be high, the promise of leveraging quantum mechanics to solve complex problems is indisputable.
